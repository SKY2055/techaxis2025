# %%
-10//3
# Out:
# -4

# %%
-10/3
# Out:
# -3.3333333333333335

# %%
is_student = True
has_id = True
in_dress = False

# %%
if is_student and has_id and in_dress:
    print("Entry Allowed. Can enter classroom.")

elif is_student and in_dress or has_id:
    print("Partially Entry allowed.")
    if is_student and has_id:
        print("Not allowed in classroom.")

else:
    print("Not allowed.")
# Out:
# Partially Entry allowed.
# Not allowed in classroom.

# %%
2**3**0
# Out:
# 2

# %%
print(10 if 5>3 else 20)
# Out:
# 10

# %%
a=[1,2,3]

if 1 in a:
    print("Yes")
# Out:
# Yes

# %%
a = [1,2,3]
b=a
c=[1,2,3]

print(a is c)
print(a is not c)
# Out:
# False
# True

# %%
-10//2
# Out:
# -5
